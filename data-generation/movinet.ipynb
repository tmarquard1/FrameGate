# %%
from google.colab import drive
drive.mount('/gdrive')

# %cd /gdrive/MyDrive/MSCE/FrameGate
# !pwd
# !ls
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/MSCE/FrameGate
# /gdrive/MyDrive/MSCE/FrameGate
# Clapping.mp4  movinet.ipynb

# %% [markdown]
# ## Setup
#
# For inference on smaller models (A0-A2), CPU is sufficient for this Colab.

# %%
# !sudo apt update
# !sudo apt install -y ffmpeg
# Out:
# Get:1 http://deb.debian.org/debian bookworm InRelease [151 kB]
# Get:2 http://deb.debian.org/debian bookworm-updates InRelease [55.4 kB]
# Get:3 http://deb.debian.org/debian-security bookworm-security InRelease [48.0 kB]m
# Get:4 http://deb.debian.org/debian bookworm/main arm64 Packages [8688 kB]
# Get:5 https://dl.yarnpkg.com/debian stable InRelease [17.1 kB]
# Get:6 https://dl.yarnpkg.com/debian stable/main arm64 Packages [10.9 kB]
# Get:7 https://dl.yarnpkg.com/debian stable/main all Packages [10.9 kB]
# Get:8 http://deb.debian.org/debian bookworm-updates/main arm64 Packages [2468 B]3m
# Get:9 http://deb.debian.org/debian-security bookworm-security/main arm64 Packages [187 kB]
# Fetched 9171 kB in 1s (6421 kB/s)3m
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 42 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   alsa-topology-conf alsa-ucm-conf dbus dbus-bin dbus-daemon
#   dbus-session-bus-common dbus-system-bus-common fontconfig libaacs0 libaom3
#   libapparmor1 libasound2 libasound2-data libass9 libasyncns0 libavc1394-0
#   libavcodec59 libavdevice59 libavfilter8 libavformat59 libavutil57 libbdplus0
#   libblas3 libbluray2 libbs2b0 libcaca0 libcairo-gobject2 libcairo2
#   libcdio-cdda2 libcdio-paranoia2 libcdio19 libchromaprint1 libcjson1
#   libcodec2-1.0 libdatrie1 libdav1d6 libdbus-1-3 libdc1394-25 libdecor-0-0
#   libdecor-0-plugin-1-cairo libdeflate0 libdrm-amdgpu1 libdrm-common
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libepoxy0 libflac12 libflite1
#   libfribidi0 libgbm1 libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgfortran5 libgl1 libgl1-mesa-dri libglapi-mesa
#   libglvnd0 libglx-mesa0 libglx0 libgme0 libgraphite2-3 libgsm1 libharfbuzz0b
#   libhwy1 libiec61883-0 libjack-jackd2-0 libjbig0 libjxl0.7 liblapack3
#   liblcms2-2 liblerc4 liblilv-0-0 libllvm15 libmbedcrypto7 libmp3lame0
#   libmpg123-0 libmysofa1 libnorm1 libogg0 libopenal-data libopenal1
#   libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpgm-5.3-0 libpixman-1-0 libplacebo208 libpocketsphinx3
#   libpostproc56 libpulse0 librabbitmq4 librav1e0 libraw1394-11 librist4
#   librsvg2-2 librsvg2-common librubberband2 libsamplerate0 libsdl2-2.0-0
#   libsensors-config libsensors5 libserd-0-0 libshine3 libslang2 libsnappy1v5
#   libsndfile1 libsndio7.0 libsodium23 libsord-0-0 libsoxr0 libspeex1
#   libsphinxbase3 libsratom-0-0 libsrt1.5-gnutls libssh-gcrypt-4 libsvtav1enc1
#   libswresample4 libswscale6 libthai-data libthai0 libtheora0 libtiff6
#   libtwolame0 libudfread0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2
#   libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx7 libvulkan1 libwayland-client0 libwayland-cursor0
#   libwayland-egl1 libwayland-server0 libx11-xcb1 libx264-164 libx265-199
#   libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0
#   libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1 libxcb-xfixes0
#   libxcursor1 libxfixes3 libxi6 libxkbcommon0 libxrandr2 libxshmfence1 libxv1
#   libxvidcore4 libxxf86vm1 libz3-4 libzimg2 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1
#   pocketsphinx-en-us va-driver-all vdpau-driver-all xkb-data
# Suggested packages:
#   default-dbus-session-bus | dbus-session-bus ffmpeg-doc libasound2-plugins
#   alsa-utils libcuda1 libnvcuvid1 libnvidia-encode1 libbluray-bdj jackd2
#   liblcms2-utils libportaudio2 opus-tools pulseaudio libraw1394-doc
#   librsvg2-bin xdg-utils lm-sensors serdi sndiod sordi speex opencl-icd
#   nvidia-vdpau-driver
# The following NEW packages will be installed:
#   alsa-topology-conf alsa-ucm-conf dbus dbus-bin dbus-daemon
#   dbus-session-bus-common dbus-system-bus-common ffmpeg fontconfig libaacs0
#   libaom3 libapparmor1 libasound2 libasound2-data libass9 libasyncns0
#   libavc1394-0 libavcodec59 libavdevice59 libavfilter8 libavformat59
#   libavutil57 libbdplus0 libblas3 libbluray2 libbs2b0 libcaca0
#   libcairo-gobject2 libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio19
#   libchromaprint1 libcjson1 libcodec2-1.0 libdatrie1 libdav1d6 libdbus-1-3
#   libdc1394-25 libdecor-0-0 libdecor-0-plugin-1-cairo libdeflate0
#   libdrm-amdgpu1 libdrm-common libdrm-nouveau2 libdrm-radeon1 libdrm2
#   libepoxy0 libflac12 libflite1 libfribidi0 libgbm1 libgdk-pixbuf-2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgfortran5 libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0
#   libgraphite2-3 libgsm1 libharfbuzz0b libhwy1 libiec61883-0 libjack-jackd2-0
#   libjbig0 libjxl0.7 liblapack3 liblcms2-2 liblerc4 liblilv-0-0 libllvm15
#   libmbedcrypto7 libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libogg0
#   libopenal-data libopenal1 libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpgm-5.3-0 libpixman-1-0
#   libplacebo208 libpocketsphinx3 libpostproc56 libpulse0 librabbitmq4
#   librav1e0 libraw1394-11 librist4 librsvg2-2 librsvg2-common librubberband2
#   libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5 libserd-0-0
#   libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0 libsodium23
#   libsord-0-0 libsoxr0 libspeex1 libsphinxbase3 libsratom-0-0 libsrt1.5-gnutls
#   libssh-gcrypt-4 libsvtav1enc1 libswresample4 libswscale6 libthai-data
#   libthai0 libtheora0 libtiff6 libtwolame0 libudfread0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau-va-gl1 libvdpau1 libvidstab1.1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx7 libvulkan1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libx11-xcb1
#   libx264-164 libx265-199 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxkbcommon0
#   libxrandr2 libxshmfence1 libxv1 libxvidcore4 libxxf86vm1 libz3-4 libzimg2
#   libzmq5 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   mesa-vulkan-drivers ocl-icd-libopencl1 pocketsphinx-en-us va-driver-all
#   vdpau-driver-all xkb-data
# 0 upgraded, 181 newly installed, 0 to remove and 42 not upgraded.
# Need to get 133 MB of archives.
# After this operation, 434 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian bookworm/main arm64 libdbus-1-3 arm64 1.14.10-1~deb12u1 [193 kB]
# Get:2 http://deb.debian.org/debian bookworm/main arm64 dbus-bin arm64 1.14.10-1~deb12u1 [104 kB]
# Get:3 http://deb.debian.org/debian bookworm/main arm64 dbus-session-bus-common all 1.14.10-1~deb12u1 [78.2 kB]
# Get:4 http://deb.debian.org/debian bookworm/main arm64 libapparmor1 arm64 3.0.8-3 [40.3 kB]
# Get:5 http://deb.debian.org/debian bookworm/main arm64 dbus-daemon arm64 1.14.10-1~deb12u1 [176 kB]
# Get:6 http://deb.debian.org/debian bookworm/main arm64 dbus-system-bus-common all 1.14.10-1~deb12u1 [79.3 kB]
# Get:7 http://deb.debian.org/debian bookworm/main arm64 dbus arm64 1.14.10-1~deb12u1 [96.2 kB]
# Get:8 http://deb.debian.org/debian bookworm/main arm64 alsa-topology-conf all 1.2.5.1-2 [15.2 kB]
# Get:9 http://deb.debian.org/debian bookworm/main arm64 libasound2-data all 1.2.8-1 [20.5 kB]
# Get:10 http://deb.debian.org/debian bookworm/main arm64 libasound2 arm64 1.2.8-1+b1 [327 kB]
# Get:11 http://deb.debian.org/debian bookworm/main arm64 alsa-ucm-conf all 1.2.8-1 [51.7 kB]
# Get:12 http://deb.debian.org/debian bookworm/main arm64 libaom3 arm64 3.6.0-1+deb12u1 [1379 kB]
# Get:13 http://deb.debian.org/debian bookworm/main arm64 libdrm-common all 2.4.114-1 [7112 B]
# Get:14 http://deb.debian.org/debian bookworm/main arm64 libdrm2 arm64 2.4.114-1+b1 [36.7 kB]
# Get:15 http://deb.debian.org/debian bookworm/main arm64 libva2 arm64 2.17.0-1 [65.2 kB]
# Get:16 http://deb.debian.org/debian bookworm/main arm64 libva-drm2 arm64 2.17.0-1 [16.3 kB]
# Get:17 http://deb.debian.org/debian bookworm/main arm64 libx11-xcb1 arm64 2:1.8.4-2+deb12u2 [192 kB]
# Get:18 http://deb.debian.org/debian bookworm/main arm64 libxcb-dri3-0 arm64 1.15-1 [107 kB]
# Get:19 http://deb.debian.org/debian bookworm/main arm64 libxfixes3 arm64 1:6.0.0-2 [22.9 kB]
# Get:20 http://deb.debian.org/debian bookworm/main arm64 libva-x11-2 arm64 2.17.0-1 [20.8 kB]
# Get:21 http://deb.debian.org/debian bookworm/main arm64 libvdpau1 arm64 1.5-2 [23.7 kB]
# Get:22 http://deb.debian.org/debian bookworm/main arm64 ocl-icd-libopencl1 arm64 2.3.1-1 [42.1 kB]
# Get:23 http://deb.debian.org/debian bookworm/main arm64 libavutil57 arm64 7:5.1.6-0+deb12u1 [333 kB]
# Get:24 http://deb.debian.org/debian bookworm/main arm64 libpixman-1-0 arm64 0.42.2-1 [470 kB]
# Get:25 http://deb.debian.org/debian bookworm/main arm64 libxcb-render0 arm64 1.15-1 [115 kB]
# Get:26 http://deb.debian.org/debian bookworm/main arm64 libxcb-shm0 arm64 1.15-1 [106 kB]
# Get:27 http://deb.debian.org/debian bookworm/main arm64 libcairo2 arm64 1.16.0-7 [527 kB]
# Get:28 http://deb.debian.org/debian bookworm/main arm64 libcodec2-1.0 arm64 1.0.5-1 [8163 kB]
# Get:29 http://deb.debian.org/debian bookworm/main arm64 libdav1d6 arm64 1.0.0-2+deb12u1 [275 kB]
# Get:30 http://deb.debian.org/debian bookworm/main arm64 libgsm1 arm64 1.0.22-1 [28.8 kB]
# Get:31 http://deb.debian.org/debian bookworm/main arm64 libhwy1 arm64 1.0.3-3+deb12u1 [226 kB]
# Get:32 http://deb.debian.org/debian bookworm/main arm64 liblcms2-2 arm64 2.14-2 [143 kB]
# Get:33 http://deb.debian.org/debian bookworm/main arm64 libjxl0.7 arm64 0.7.0-10 [643 kB]
# Get:34 http://deb.debian.org/debian bookworm/main arm64 libmp3lame0 arm64 3.100-6 [357 kB]
# Get:35 http://deb.debian.org/debian bookworm/main arm64 libopenjp2-7 arm64 2.5.0-2 [175 kB]
# Get:36 http://deb.debian.org/debian bookworm/main arm64 libopus0 arm64 1.3.1-3 [176 kB]
# Get:37 http://deb.debian.org/debian bookworm/main arm64 librav1e0 arm64 0.5.1-6 [552 kB]
# Get:38 http://deb.debian.org/debian bookworm/main arm64 libcairo-gobject2 arm64 1.16.0-7 [112 kB]
# Get:39 http://deb.debian.org/debian bookworm/main arm64 libgdk-pixbuf2.0-common all 2.42.10+dfsg-1+deb12u1 [306 kB]
# Get:40 http://deb.debian.org/debian bookworm/main arm64 libdeflate0 arm64 1.14-1 [54.3 kB]
# Get:41 http://deb.debian.org/debian bookworm/main arm64 libjbig0 arm64 2.1-6.1 [30.0 kB]
# Get:42 http://deb.debian.org/debian bookworm/main arm64 liblerc4 arm64 4.0.0+ds-2 [138 kB]
# Get:43 http://deb.debian.org/debian bookworm/main arm64 libtiff6 arm64 4.5.0-6+deb12u1 [301 kB]
# Get:44 http://deb.debian.org/debian bookworm/main arm64 libgdk-pixbuf-2.0-0 arm64 2.42.10+dfsg-1+deb12u1 [130 kB]
# Get:45 http://deb.debian.org/debian bookworm/main arm64 fontconfig arm64 2.14.1-4 [449 kB]
# Get:46 http://deb.debian.org/debian bookworm/main arm64 libfribidi0 arm64 1.0.8-2.1 [64.9 kB]
# Get:47 http://deb.debian.org/debian bookworm/main arm64 libgraphite2-3 arm64 1.3.14-1 [75.6 kB]
# Get:48 http://deb.debian.org/debian bookworm/main arm64 libharfbuzz0b arm64 6.0.0+dfsg-3 [1914 kB]
# Get:49 http://deb.debian.org/debian bookworm/main arm64 libthai-data all 0.1.29-1 [176 kB]
# Get:50 http://deb.debian.org/debian bookworm/main arm64 libdatrie1 arm64 0.2.13-2+b1 [42.6 kB]
# Get:51 http://deb.debian.org/debian bookworm/main arm64 libthai0 arm64 0.1.29-1 [56.2 kB]
# Get:52 http://deb.debian.org/debian bookworm/main arm64 libpango-1.0-0 arm64 1.50.12+ds-1 [200 kB]
# Get:53 http://deb.debian.org/debian bookworm/main arm64 libpangoft2-1.0-0 arm64 1.50.12+ds-1 [44.5 kB]
# Get:54 http://deb.debian.org/debian bookworm/main arm64 libpangocairo-1.0-0 arm64 1.50.12+ds-1 [32.0 kB]
# Get:55 http://deb.debian.org/debian bookworm/main arm64 librsvg2-2 arm64 2.54.7+dfsg-1~deb12u1 [2290 kB]
# Get:56 http://deb.debian.org/debian bookworm/main arm64 libshine3 arm64 3.1.1-2 [23.0 kB]
# Get:57 http://deb.debian.org/debian bookworm/main arm64 libsnappy1v5 arm64 1.1.9-3 [25.4 kB]
# Get:58 http://deb.debian.org/debian bookworm/main arm64 libspeex1 arm64 1.2.1-2 [48.3 kB]
# Get:59 http://deb.debian.org/debian bookworm/main arm64 libsvtav1enc1 arm64 1.4.1+dfsg-1 [1074 kB]
# Get:60 http://deb.debian.org/debian bookworm/main arm64 libsoxr0 arm64 0.1.3-4 [54.4 kB]
# Get:61 http://deb.debian.org/debian bookworm/main arm64 libswresample4 arm64 7:5.1.6-0+deb12u1 [91.1 kB]
# Get:62 http://deb.debian.org/debian bookworm/main arm64 libogg0 arm64 1.3.5-3 [23.0 kB]
# Get:63 http://deb.debian.org/debian bookworm/main arm64 libtheora0 arm64 1.1.1+dfsg.1-16.1+b1 [144 kB]
# Get:64 http://deb.debian.org/debian bookworm/main arm64 libtwolame0 arm64 0.4.0-2 [48.5 kB]
# Get:65 http://deb.debian.org/debian bookworm/main arm64 libvorbis0a arm64 1.3.7-1 [86.2 kB]
# Get:66 http://deb.debian.org/debian bookworm/main arm64 libvorbisenc2 arm64 1.3.7-1 [80.4 kB]
# Get:67 http://deb.debian.org/debian bookworm/main arm64 libvpx7 arm64 1.12.0-1+deb12u3 [895 kB]
# Get:68 http://deb.debian.org/debian bookworm/main arm64 libx264-164 arm64 2:0.164.3095+gitbaee400-3 [443 kB]
# Get:69 http://deb.debian.org/debian bookworm/main arm64 libx265-199 arm64 3.5-2+b1 [603 kB]
# Get:70 http://deb.debian.org/debian bookworm/main arm64 libxvidcore4 arm64 2:1.3.7-1 [202 kB]
# Get:71 http://deb.debian.org/debian bookworm/main arm64 libzvbi-common all 0.2.41-1 [69.7 kB]
# Get:72 http://deb.debian.org/debian bookworm/main arm64 libzvbi0 arm64 0.2.41-1 [258 kB]
# Get:73 http://deb.debian.org/debian bookworm/main arm64 libavcodec59 arm64 7:5.1.6-0+deb12u1 [4785 kB]
# Get:74 http://deb.debian.org/debian bookworm/main arm64 libraw1394-11 arm64 2.1.2-2 [40.3 kB]
# Get:75 http://deb.debian.org/debian bookworm/main arm64 libavc1394-0 arm64 0.5.4-5 [18.4 kB]
# Get:76 http://deb.debian.org/debian bookworm/main arm64 libass9 arm64 1:0.17.1-1 [91.1 kB]
# Get:77 http://deb.debian.org/debian bookworm/main arm64 libudfread0 arm64 1.1.2-1 [15.7 kB]
# Get:78 http://deb.debian.org/debian bookworm/main arm64 libbluray2 arm64 1:1.3.4-1 [124 kB]
# Get:79 http://deb.debian.org/debian bookworm/main arm64 libchromaprint1 arm64 1.5.1-2+b1 [37.4 kB]
# Get:80 http://deb.debian.org/debian bookworm/main arm64 libgme0 arm64 0.6.3-6 [118 kB]
# Get:81 http://deb.debian.org/debian bookworm/main arm64 libmpg123-0 arm64 1.31.2-1 [140 kB]
# Get:82 http://deb.debian.org/debian bookworm/main arm64 libvorbisfile3 arm64 1.3.7-1 [25.4 kB]
# Get:83 http://deb.debian.org/debian bookworm/main arm64 libopenmpt0 arm64 0.6.9-1 [622 kB]
# Get:84 http://deb.debian.org/debian bookworm/main arm64 librabbitmq4 arm64 0.11.0-1+b1 [41.9 kB]
# Get:85 http://deb.debian.org/debian bookworm/main arm64 libcjson1 arm64 1.7.15-1+deb12u2 [22.4 kB]
# Get:86 http://deb.debian.org/debian bookworm/main arm64 libmbedcrypto7 arm64 2.28.3-1 [263 kB]
# Get:87 http://deb.debian.org/debian bookworm/main arm64 librist4 arm64 0.2.7+dfsg-1 [69.6 kB]
# Get:88 http://deb.debian.org/debian bookworm/main arm64 libsrt1.5-gnutls arm64 1.5.1-1 [272 kB]
# Get:89 http://deb.debian.org/debian bookworm/main arm64 libssh-gcrypt-4 arm64 0.10.6-0+deb12u1 [207 kB]
# Get:90 http://deb.debian.org/debian bookworm/main arm64 libnorm1 arm64 1.5.9+dfsg-2 [202 kB]
# Get:91 http://deb.debian.org/debian bookworm/main arm64 libpgm-5.3-0 arm64 5.3.128~dfsg-2 [152 kB]
# Get:92 http://deb.debian.org/debian bookworm/main arm64 libsodium23 arm64 1.0.18-1 [119 kB]
# Get:93 http://deb.debian.org/debian bookworm/main arm64 libzmq5 arm64 4.3.4-6 [244 kB]
# Get:94 http://deb.debian.org/debian bookworm/main arm64 libavformat59 arm64 7:5.1.6-0+deb12u1 [1043 kB]
# Get:95 http://deb.debian.org/debian bookworm/main arm64 libbs2b0 arm64 3.1.0+dfsg-7 [10.7 kB]
# Get:96 http://deb.debian.org/debian bookworm/main arm64 libflite1 arm64 2.2-5 [12.8 MB]
# Get:97 http://deb.debian.org/debian bookworm/main arm64 libserd-0-0 arm64 0.30.16-1 [44.7 kB]
# Get:98 http://deb.debian.org/debian bookworm/main arm64 libsord-0-0 arm64 0.16.14+git221008-1 [20.0 kB]
# Get:99 http://deb.debian.org/debian bookworm/main arm64 libsratom-0-0 arm64 0.6.14-1 [15.9 kB]
# Get:100 http://deb.debian.org/debian bookworm/main arm64 liblilv-0-0 arm64 0.24.14-1 [46.8 kB]
# Get:101 http://deb.debian.org/debian bookworm/main arm64 libmysofa1 arm64 1.3.1~dfsg0-1 [1156 kB]
# Get:102 http://deb.debian.org/debian bookworm/main arm64 libepoxy0 arm64 1.5.10-1 [198 kB]
# Get:103 http://deb.debian.org/debian bookworm/main arm64 libvulkan1 arm64 1.3.239.0-1 [111 kB]
# Get:104 http://deb.debian.org/debian bookworm/main arm64 libplacebo208 arm64 4.208.0-3 [2004 kB]
# Get:105 http://deb.debian.org/debian bookworm/main arm64 libblas3 arm64 3.11.0-2 [91.4 kB]
# Get:106 http://deb.debian.org/debian bookworm/main arm64 libgfortran5 arm64 12.2.0-14 [340 kB]
# Get:107 http://deb.debian.org/debian bookworm/main arm64 liblapack3 arm64 3.11.0-2 [1664 kB]
# Get:108 http://deb.debian.org/debian bookworm/main arm64 libasyncns0 arm64 0.8-6+b3 [12.5 kB]
# Get:109 http://deb.debian.org/debian bookworm/main arm64 libflac12 arm64 1.4.2+ds-2 [161 kB]
# Get:110 http://deb.debian.org/debian bookworm/main arm64 libsndfile1 arm64 1.2.0-1 [183 kB]
# Get:111 http://deb.debian.org/debian bookworm/main arm64 libpulse0 arm64 16.1+dfsg1-2+b1 [231 kB]
# Get:112 http://deb.debian.org/debian bookworm/main arm64 libsphinxbase3 arm64 0.8+5prealpha+1-16 [109 kB]
# Get:113 http://deb.debian.org/debian bookworm/main arm64 libpocketsphinx3 arm64 0.8+5prealpha+1-15 [114 kB]
# Get:114 http://deb.debian.org/debian bookworm/main arm64 libpostproc56 arm64 7:5.1.6-0+deb12u1 [75.2 kB]
# Get:115 http://deb.debian.org/debian bookworm/main arm64 librubberband2 arm64 3.1.2+dfsg0-1 [118 kB]
# Get:116 http://deb.debian.org/debian bookworm/main arm64 libswscale6 arm64 7:5.1.6-0+deb12u1 [182 kB]
# Get:117 http://deb.debian.org/debian bookworm/main arm64 libvidstab1.1 arm64 1.1.0-2+b1 [36.4 kB]
# Get:118 http://deb.debian.org/debian bookworm/main arm64 libzimg2 arm64 3.0.4+ds1-1 [110 kB]
# Get:119 http://deb.debian.org/debian bookworm/main arm64 libavfilter8 arm64 7:5.1.6-0+deb12u1 [3309 kB]
# Get:120 http://deb.debian.org/debian bookworm/main arm64 libslang2 arm64 2.3.3-3 [502 kB]
# Get:121 http://deb.debian.org/debian bookworm/main arm64 libcaca0 arm64 0.99.beta20-3 [200 kB]
# Get:122 http://deb.debian.org/debian bookworm/main arm64 libcdio19 arm64 2.1.0-4 [201 kB]
# Get:123 http://deb.debian.org/debian bookworm/main arm64 libcdio-cdda2 arm64 10.2+2.0.1-1 [20.1 kB]
# Get:124 http://deb.debian.org/debian bookworm/main arm64 libcdio-paranoia2 arm64 10.2+2.0.1-1 [19.6 kB]
# Get:125 http://deb.debian.org/debian bookworm/main arm64 libusb-1.0-0 arm64 2:1.0.26-1 [60.0 kB]
# Get:126 http://deb.debian.org/debian bookworm/main arm64 libdc1394-25 arm64 2.2.6-4 [105 kB]
# Get:127 http://deb.debian.org/debian bookworm/main arm64 libglvnd0 arm64 1.6.0-1 [41.4 kB]
# Get:128 http://deb.debian.org/debian bookworm/main arm64 libglapi-mesa arm64 22.3.6-1+deb12u1 [44.7 kB]
# Get:129 http://deb.debian.org/debian bookworm/main arm64 libxcb-dri2-0 arm64 1.15-1 [107 kB]
# Get:130 http://deb.debian.org/debian bookworm/main arm64 libxcb-glx0 arm64 1.15-1 [123 kB]
# Get:131 http://deb.debian.org/debian bookworm/main arm64 libxcb-present0 arm64 1.15-1 [106 kB]
# Get:132 http://deb.debian.org/debian bookworm/main arm64 libxcb-randr0 arm64 1.15-1 [117 kB]
# Get:133 http://deb.debian.org/debian bookworm/main arm64 libxcb-sync1 arm64 1.15-1 [109 kB]
# Get:134 http://deb.debian.org/debian bookworm/main arm64 libxcb-xfixes0 arm64 1.15-1 [110 kB]
# Get:135 http://deb.debian.org/debian bookworm/main arm64 libxshmfence1 arm64 1.3-1 [8712 B]
# Get:136 http://deb.debian.org/debian bookworm/main arm64 libxxf86vm1 arm64 1:1.1.4-1+b2 [20.1 kB]
# Get:137 http://deb.debian.org/debian bookworm/main arm64 libdrm-amdgpu1 arm64 2.4.114-1+b1 [20.4 kB]
# Get:138 http://deb.debian.org/debian bookworm/main arm64 libdrm-nouveau2 arm64 2.4.114-1+b1 [18.4 kB]
# Get:139 http://deb.debian.org/debian bookworm/main arm64 libdrm-radeon1 arm64 2.4.114-1+b1 [20.9 kB]
# Get:140 http://deb.debian.org/debian bookworm/main arm64 libz3-4 arm64 4.8.12-3.1 [6282 kB]
# Get:141 http://deb.debian.org/debian bookworm/main arm64 libllvm15 arm64 1:15.0.6-4+b1 [20.7 MB]
# Get:142 http://deb.debian.org/debian bookworm/main arm64 libsensors-config all 1:3.6.0-7.1 [14.3 kB]
# Get:143 http://deb.debian.org/debian bookworm/main arm64 libsensors5 arm64 1:3.6.0-7.1 [33.3 kB]
# Get:144 http://deb.debian.org/debian bookworm/main arm64 libgl1-mesa-dri arm64 22.3.6-1+deb12u1 [6278 kB]
# Get:145 http://deb.debian.org/debian bookworm/main arm64 libglx-mesa0 arm64 22.3.6-1+deb12u1 [146 kB]
# Get:146 http://deb.debian.org/debian bookworm/main arm64 libglx0 arm64 1.6.0-1 [30.8 kB]
# Get:147 http://deb.debian.org/debian bookworm/main arm64 libgl1 arm64 1.6.0-1 [90.2 kB]m
# Get:148 http://deb.debian.org/debian bookworm/main arm64 libiec61883-0 arm64 1.2.0-6+b1 [29.0 kB]
# Get:149 http://deb.debian.org/debian bookworm/main arm64 libsamplerate0 arm64 0.2.2-3 [945 kB]
# Get:150 http://deb.debian.org/debian bookworm/main arm64 libjack-jackd2-0 arm64 1.9.21~dfsg-3 [261 kB]
# Get:151 http://deb.debian.org/debian bookworm/main arm64 libopenal-data all 1:1.19.1-2 [170 kB]
# Get:152 http://deb.debian.org/debian bookworm/main arm64 libsndio7.0 arm64 1.9.0-0.3+b2 [25.7 kB]
# Get:153 http://deb.debian.org/debian bookworm/main arm64 libopenal1 arm64 1:1.19.1-2 [485 kB]
# Get:154 http://deb.debian.org/debian bookworm/main arm64 libwayland-client0 arm64 1.21.0-1 [27.6 kB]
# Get:155 http://deb.debian.org/debian bookworm/main arm64 libdecor-0-0 arm64 0.1.1-2 [14.2 kB]
# Get:156 http://deb.debian.org/debian bookworm/main arm64 libwayland-server0 arm64 1.21.0-1 [34.9 kB]
# Get:157 http://deb.debian.org/debian bookworm/main arm64 libgbm1 arm64 22.3.6-1+deb12u1 [37.0 kB]
# Get:158 http://deb.debian.org/debian bookworm/main arm64 libwayland-cursor0 arm64 1.21.0-1 [14.1 kB]
# Get:159 http://deb.debian.org/debian bookworm/main arm64 libwayland-egl1 arm64 1.21.0-1 [8696 B]
# Get:160 http://deb.debian.org/debian bookworm/main arm64 libxcursor1 arm64 1:1.2.1-1 [40.2 kB]
# Get:161 http://deb.debian.org/debian bookworm/main arm64 libxi6 arm64 2:1.8-1+b1 [82.3 kB]
# Get:162 http://deb.debian.org/debian bookworm/main arm64 xkb-data all 2.35.1-1 [764 kB]m
# Get:163 http://deb.debian.org/debian bookworm/main arm64 libxkbcommon0 arm64 1.5.0-1 [100 kB]
# Get:164 http://deb.debian.org/debian bookworm/main arm64 libxrandr2 arm64 2:1.5.2-2+b1 [38.4 kB]
# Get:165 http://deb.debian.org/debian bookworm/main arm64 libsdl2-2.0-0 arm64 2.26.5+dfsg-1 [566 kB]
# Get:166 http://deb.debian.org/debian bookworm/main arm64 libxcb-shape0 arm64 1.15-1 [106 kB]
# Get:167 http://deb.debian.org/debian bookworm/main arm64 libxv1 arm64 2:1.0.11-1.1 [24.5 kB]
# Get:168 http://deb.debian.org/debian bookworm/main arm64 libavdevice59 arm64 7:5.1.6-0+deb12u1 [112 kB]
# Get:169 http://deb.debian.org/debian bookworm/main arm64 ffmpeg arm64 7:5.1.6-0+deb12u1 [1803 kB]
# Get:170 http://deb.debian.org/debian bookworm/main arm64 libaacs0 arm64 0.11.1-2 [51.3 kB]
# Get:171 http://deb.debian.org/debian bookworm/main arm64 libbdplus0 arm64 0.2.0-3 [47.4 kB]
# Get:172 http://deb.debian.org/debian bookworm/main arm64 libdecor-0-plugin-1-cairo arm64 0.1.1-2 [18.3 kB]
# Get:173 http://deb.debian.org/debian bookworm/main arm64 libgdk-pixbuf2.0-bin arm64 2.42.10+dfsg-1+deb12u1 [17.9 kB]
# Get:174 http://deb.debian.org/debian bookworm/main arm64 librsvg2-common arm64 2.54.7+dfsg-1~deb12u1 [21.4 kB]
# Get:175 http://deb.debian.org/debian bookworm/main arm64 libvdpau-va-gl1 arm64 0.4.2-1+b1 [66.7 kB]
# Get:176 http://deb.debian.org/debian bookworm/main arm64 mesa-va-drivers arm64 22.3.6-1+deb12u1 [2964 kB]
# Get:177 http://deb.debian.org/debian bookworm/main arm64 mesa-vdpau-drivers arm64 22.3.6-1+deb12u1 [2853 kB]
# Get:178 http://deb.debian.org/debian bookworm/main arm64 mesa-vulkan-drivers arm64 22.3.6-1+deb12u1 [3826 kB]
# Get:179 http://deb.debian.org/debian bookworm/main arm64 pocketsphinx-en-us all 0.8+5prealpha+1-15 [24.3 MB]
# Get:180 http://deb.debian.org/debian bookworm/main arm64 va-driver-all arm64 2.17.0-1 [12.8 kB]33m
# Get:181 http://deb.debian.org/debian bookworm/main arm64 vdpau-driver-all arm64 1.5-2 [4320 B]
# Fetched 133 MB in 12s (10.8 MB/s)
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package libdbus-1-3:arm64.
# (Reading database ... 29683 files and directories currently installed.)
# Preparing to unpack .../000-libdbus-1-3_1.14.10-1~deb12u1_arm64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libdbus-1-3:arm64 (1.14.10-1~deb12u1) ...
# Selecting previously unselected package dbus-bin.
# Preparing to unpack .../001-dbus-bin_1.14.10-1~deb12u1_arm64.deb ...
# Unpacking dbus-bin (1.14.10-1~deb12u1) ...
# Selecting previously unselected package dbus-session-bus-common.
# Preparing to unpack .../002-dbus-session-bus-common_1.14.10-1~deb12u1_all.deb ...
# Unpacking dbus-session-bus-common (1.14.10-1~deb12u1) ...
# Selecting previously unselected package libapparmor1:arm64.
# Preparing to unpack .../003-libapparmor1_3.0.8-3_arm64.deb ...
# Unpacking libapparmor1:arm64 (3.0.8-3) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package dbus-daemon.
# Preparing to unpack .../004-dbus-daemon_1.14.10-1~deb12u1_arm64.deb ...
# Unpacking dbus-daemon (1.14.10-1~deb12u1) ...
# Selecting previously unselected package dbus-system-bus-common.
# Preparing to unpack .../005-dbus-system-bus-common_1.14.10-1~deb12u1_all.deb ...
# Unpacking dbus-system-bus-common (1.14.10-1~deb12u1) ...
# Selecting previously unselected package dbus.
# Preparing to unpack .../006-dbus_1.14.10-1~deb12u1_arm64.deb ...
# Unpacking dbus (1.14.10-1~deb12u1) ...
# Selecting previously unselected package alsa-topology-conf.
# Preparing to unpack .../007-alsa-topology-conf_1.2.5.1-2_all.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking alsa-topology-conf (1.2.5.1-2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../008-libasound2-data_1.2.8-1_all.deb ...
# Unpacking libasound2-data (1.2.8-1) ...
# Selecting previously unselected package libasound2:arm64.
# Preparing to unpack .../009-libasound2_1.2.8-1+b1_arm64.deb ...
# Unpacking libasound2:arm64 (1.2.8-1+b1) ...
# Selecting previously unselected package alsa-ucm-conf.
# Preparing to unpack .../010-alsa-ucm-conf_1.2.8-1_all.deb ...
# Unpacking alsa-ucm-conf (1.2.8-1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libaom3:arm64.
# Preparing to unpack .../011-libaom3_3.6.0-1+deb12u1_arm64.deb ...
# Unpacking libaom3:arm64 (3.6.0-1+deb12u1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../012-libdrm-common_2.4.114-1_all.deb ...
# Unpacking libdrm-common (2.4.114-1) ...
# Selecting previously unselected package libdrm2:arm64.
# Preparing to unpack .../013-libdrm2_2.4.114-1+b1_arm64.deb ...
# Unpacking libdrm2:arm64 (2.4.114-1+b1) ...
# Selecting previously unselected package libva2:arm64.
# Preparing to unpack .../014-libva2_2.17.0-1_arm64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libva2:arm64 (2.17.0-1) ...
# Selecting previously unselected package libva-drm2:arm64.
# Preparing to unpack .../015-libva-drm2_2.17.0-1_arm64.deb ...
# Unpacking libva-drm2:arm64 (2.17.0-1) ...
# Selecting previously unselected package libx11-xcb1:arm64.
# Preparing to unpack .../016-libx11-xcb1_2%3a1.8.4-2+deb12u2_arm64.deb ...
# Unpacking libx11-xcb1:arm64 (2:1.8.4-2+deb12u2) ...
# Selecting previously unselected package libxcb-dri3-0:arm64.
# Preparing to unpack .../017-libxcb-dri3-0_1.15-1_arm64.deb ...
# Unpacking libxcb-dri3-0:arm64 (1.15-1) ...
# Selecting previously unselected package libxfixes3:arm64.
# Preparing to unpack .../018-libxfixes3_1%3a6.0.0-2_arm64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libxfixes3:arm64 (1:6.0.0-2) ...
# Selecting previously unselected package libva-x11-2:arm64.
# Preparing to unpack .../019-libva-x11-2_2.17.0-1_arm64.deb ...
# Unpacking libva-x11-2:arm64 (2.17.0-1) ...
# Selecting previously unselected package libvdpau1:arm64.
# Preparing to unpack .../020-libvdpau1_1.5-2_arm64.deb ...
# Unpacking libvdpau1:arm64 (1.5-2) ...
# Selecting previously unselected package ocl-icd-libopencl1:arm64.
# Preparing to unpack .../021-ocl-icd-libopencl1_2.3.1-1_arm64.deb ...
# Unpacking ocl-icd-libopencl1:arm64 (2.3.1-1) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libavutil57:arm64.
# Preparing to unpack .../022-libavutil57_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libavutil57:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libpixman-1-0:arm64.
# Preparing to unpack .../023-libpixman-1-0_0.42.2-1_arm64.deb ...
# Unpacking libpixman-1-0:arm64 (0.42.2-1) ...
# Selecting previously unselected package libxcb-render0:arm64.
# Preparing to unpack .../024-libxcb-render0_1.15-1_arm64.deb ...
# Unpacking libxcb-render0:arm64 (1.15-1) ...
# Selecting previously unselected package libxcb-shm0:arm64.
# Preparing to unpack .../025-libxcb-shm0_1.15-1_arm64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libxcb-shm0:arm64 (1.15-1) ...
# Selecting previously unselected package libcairo2:arm64.
# Preparing to unpack .../026-libcairo2_1.16.0-7_arm64.deb ...
# Unpacking libcairo2:arm64 (1.16.0-7) ...
# Selecting previously unselected package libcodec2-1.0:arm64.
# Preparing to unpack .../027-libcodec2-1.0_1.0.5-1_arm64.deb ...
# Unpacking libcodec2-1.0:arm64 (1.0.5-1) ...
# Selecting previously unselected package libdav1d6:arm64.
# Preparing to unpack .../028-libdav1d6_1.0.0-2+deb12u1_arm64.deb ...
# Unpacking libdav1d6:arm64 (1.0.0-2+deb12u1) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libgsm1:arm64.
# Preparing to unpack .../029-libgsm1_1.0.22-1_arm64.deb ...
# Unpacking libgsm1:arm64 (1.0.22-1) ...
# Selecting previously unselected package libhwy1:arm64.
# Preparing to unpack .../030-libhwy1_1.0.3-3+deb12u1_arm64.deb ...
# Unpacking libhwy1:arm64 (1.0.3-3+deb12u1) ...
# Selecting previously unselected package liblcms2-2:arm64.
# Preparing to unpack .../031-liblcms2-2_2.14-2_arm64.deb ...
# Unpacking liblcms2-2:arm64 (2.14-2) ...
# Selecting previously unselected package libjxl0.7:arm64.
# Preparing to unpack .../032-libjxl0.7_0.7.0-10_arm64.deb ...
# Unpacking libjxl0.7:arm64 (0.7.0-10) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libmp3lame0:arm64.
# Preparing to unpack .../033-libmp3lame0_3.100-6_arm64.deb ...
# Unpacking libmp3lame0:arm64 (3.100-6) ...
# Selecting previously unselected package libopenjp2-7:arm64.
# Preparing to unpack .../034-libopenjp2-7_2.5.0-2_arm64.deb ...
# Unpacking libopenjp2-7:arm64 (2.5.0-2) ...
# Selecting previously unselected package libopus0:arm64.
# Preparing to unpack .../035-libopus0_1.3.1-3_arm64.deb ...
# Unpacking libopus0:arm64 (1.3.1-3) ...
# Selecting previously unselected package librav1e0:arm64.
# Preparing to unpack .../036-librav1e0_0.5.1-6_arm64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking librav1e0:arm64 (0.5.1-6) ...
# Selecting previously unselected package libcairo-gobject2:arm64.
# Preparing to unpack .../037-libcairo-gobject2_1.16.0-7_arm64.deb ...
# Unpacking libcairo-gobject2:arm64 (1.16.0-7) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../038-libgdk-pixbuf2.0-common_2.42.10+dfsg-1+deb12u1_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.42.10+dfsg-1+deb12u1) ...
# Selecting previously unselected package libdeflate0:arm64.
# Preparing to unpack .../039-libdeflate0_1.14-1_arm64.deb ...
# Unpacking libdeflate0:arm64 (1.14-1) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libjbig0:arm64.
# Preparing to unpack .../040-libjbig0_2.1-6.1_arm64.deb ...
# Unpacking libjbig0:arm64 (2.1-6.1) ...
# Selecting previously unselected package liblerc4:arm64.
# Preparing to unpack .../041-liblerc4_4.0.0+ds-2_arm64.deb ...
# Unpacking liblerc4:arm64 (4.0.0+ds-2) ...
# Selecting previously unselected package libtiff6:arm64.
# Preparing to unpack .../042-libtiff6_4.5.0-6+deb12u1_arm64.deb ...
# Unpacking libtiff6:arm64 (4.5.0-6+deb12u1) ...
# Selecting previously unselected package libgdk-pixbuf-2.0-0:arm64.
# Preparing to unpack .../043-libgdk-pixbuf-2.0-0_2.42.10+dfsg-1+deb12u1_arm64.deb ...
# 7Progress: [ 12%] [######....................................................] 8Unpacking libgdk-pixbuf-2.0-0:arm64 (2.42.10+dfsg-1+deb12u1) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../044-fontconfig_2.14.1-4_arm64.deb ...
# Unpacking fontconfig (2.14.1-4) ...
# Selecting previously unselected package libfribidi0:arm64.
# Preparing to unpack .../045-libfribidi0_1.0.8-2.1_arm64.deb ...
# Unpacking libfribidi0:arm64 (1.0.8-2.1) ...
# Selecting previously unselected package libgraphite2-3:arm64.
# Preparing to unpack .../046-libgraphite2-3_1.3.14-1_arm64.deb ...
# Unpacking libgraphite2-3:arm64 (1.3.14-1) ...
# Selecting previously unselected package libharfbuzz0b:arm64.
# Preparing to unpack .../047-libharfbuzz0b_6.0.0+dfsg-3_arm64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libharfbuzz0b:arm64 (6.0.0+dfsg-3) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../048-libthai-data_0.1.29-1_all.deb ...
# Unpacking libthai-data (0.1.29-1) ...
# Selecting previously unselected package libdatrie1:arm64.
# Preparing to unpack .../049-libdatrie1_0.2.13-2+b1_arm64.deb ...
# Unpacking libdatrie1:arm64 (0.2.13-2+b1) ...
# Selecting previously unselected package libthai0:arm64.
# Preparing to unpack .../050-libthai0_0.1.29-1_arm64.deb ...
# Unpacking libthai0:arm64 (0.1.29-1) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libpango-1.0-0:arm64.
# Preparing to unpack .../051-libpango-1.0-0_1.50.12+ds-1_arm64.deb ...
# Unpacking libpango-1.0-0:arm64 (1.50.12+ds-1) ...
# Selecting previously unselected package libpangoft2-1.0-0:arm64.
# Preparing to unpack .../052-libpangoft2-1.0-0_1.50.12+ds-1_arm64.deb ...
# Unpacking libpangoft2-1.0-0:arm64 (1.50.12+ds-1) ...
# Selecting previously unselected package libpangocairo-1.0-0:arm64.
# Preparing to unpack .../053-libpangocairo-1.0-0_1.50.12+ds-1_arm64.deb ...
# Unpacking libpangocairo-1.0-0:arm64 (1.50.12+ds-1) ...
# Selecting previously unselected package librsvg2-2:arm64.
# Preparing to unpack .../054-librsvg2-2_2.54.7+dfsg-1~deb12u1_arm64.deb ...
# 7Progress: [ 15%] [########..................................................] 8Unpacking librsvg2-2:arm64 (2.54.7+dfsg-1~deb12u1) ...
# Selecting previously unselected package libshine3:arm64.
# Preparing to unpack .../055-libshine3_3.1.1-2_arm64.deb ...
# Unpacking libshine3:arm64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:arm64.
# Preparing to unpack .../056-libsnappy1v5_1.1.9-3_arm64.deb ...
# Unpacking libsnappy1v5:arm64 (1.1.9-3) ...
# Selecting previously unselected package libspeex1:arm64.
# Preparing to unpack .../057-libspeex1_1.2.1-2_arm64.deb ...
# Unpacking libspeex1:arm64 (1.2.1-2) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libsvtav1enc1:arm64.
# Preparing to unpack .../058-libsvtav1enc1_1.4.1+dfsg-1_arm64.deb ...
# Unpacking libsvtav1enc1:arm64 (1.4.1+dfsg-1) ...
# Selecting previously unselected package libsoxr0:arm64.
# Preparing to unpack .../059-libsoxr0_0.1.3-4_arm64.deb ...
# Unpacking libsoxr0:arm64 (0.1.3-4) ...
# Selecting previously unselected package libswresample4:arm64.
# Preparing to unpack .../060-libswresample4_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libswresample4:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libogg0:arm64.
# Preparing to unpack .../061-libogg0_1.3.5-3_arm64.deb ...
# Unpacking libogg0:arm64 (1.3.5-3) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package libtheora0:arm64.
# Preparing to unpack .../062-libtheora0_1.1.1+dfsg.1-16.1+b1_arm64.deb ...
# Unpacking libtheora0:arm64 (1.1.1+dfsg.1-16.1+b1) ...
# Selecting previously unselected package libtwolame0:arm64.
# Preparing to unpack .../063-libtwolame0_0.4.0-2_arm64.deb ...
# Unpacking libtwolame0:arm64 (0.4.0-2) ...
# Selecting previously unselected package libvorbis0a:arm64.
# Preparing to unpack .../064-libvorbis0a_1.3.7-1_arm64.deb ...
# Unpacking libvorbis0a:arm64 (1.3.7-1) ...
# Selecting previously unselected package libvorbisenc2:arm64.
# Preparing to unpack .../065-libvorbisenc2_1.3.7-1_arm64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libvorbisenc2:arm64 (1.3.7-1) ...
# Selecting previously unselected package libvpx7:arm64.
# Preparing to unpack .../066-libvpx7_1.12.0-1+deb12u3_arm64.deb ...
# Unpacking libvpx7:arm64 (1.12.0-1+deb12u3) ...
# Selecting previously unselected package libx264-164:arm64.
# Preparing to unpack .../067-libx264-164_2%3a0.164.3095+gitbaee400-3_arm64.deb ...
# Unpacking libx264-164:arm64 (2:0.164.3095+gitbaee400-3) ...
# Selecting previously unselected package libx265-199:arm64.
# Preparing to unpack .../068-libx265-199_3.5-2+b1_arm64.deb ...
# Unpacking libx265-199:arm64 (3.5-2+b1) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libxvidcore4:arm64.
# Preparing to unpack .../069-libxvidcore4_2%3a1.3.7-1_arm64.deb ...
# Unpacking libxvidcore4:arm64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../070-libzvbi-common_0.2.41-1_all.deb ...
# Unpacking libzvbi-common (0.2.41-1) ...
# Selecting previously unselected package libzvbi0:arm64.
# Preparing to unpack .../071-libzvbi0_0.2.41-1_arm64.deb ...
# Unpacking libzvbi0:arm64 (0.2.41-1) ...
# Selecting previously unselected package libavcodec59:arm64.
# Preparing to unpack .../072-libavcodec59_7%3a5.1.6-0+deb12u1_arm64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking libavcodec59:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libraw1394-11:arm64.
# Preparing to unpack .../073-libraw1394-11_2.1.2-2_arm64.deb ...
# Unpacking libraw1394-11:arm64 (2.1.2-2) ...
# Selecting previously unselected package libavc1394-0:arm64.
# Preparing to unpack .../074-libavc1394-0_0.5.4-5_arm64.deb ...
# Unpacking libavc1394-0:arm64 (0.5.4-5) ...
# Selecting previously unselected package libass9:arm64.
# Preparing to unpack .../075-libass9_1%3a0.17.1-1_arm64.deb ...
# Unpacking libass9:arm64 (1:0.17.1-1) ...
# Selecting previously unselected package libudfread0:arm64.
# Preparing to unpack .../076-libudfread0_1.1.2-1_arm64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libudfread0:arm64 (1.1.2-1) ...
# Selecting previously unselected package libbluray2:arm64.
# Preparing to unpack .../077-libbluray2_1%3a1.3.4-1_arm64.deb ...
# Unpacking libbluray2:arm64 (1:1.3.4-1) ...
# Selecting previously unselected package libchromaprint1:arm64.
# Preparing to unpack .../078-libchromaprint1_1.5.1-2+b1_arm64.deb ...
# Unpacking libchromaprint1:arm64 (1.5.1-2+b1) ...
# Selecting previously unselected package libgme0:arm64.
# Preparing to unpack .../079-libgme0_0.6.3-6_arm64.deb ...
# Unpacking libgme0:arm64 (0.6.3-6) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libmpg123-0:arm64.
# Preparing to unpack .../080-libmpg123-0_1.31.2-1_arm64.deb ...
# Unpacking libmpg123-0:arm64 (1.31.2-1) ...
# Selecting previously unselected package libvorbisfile3:arm64.
# Preparing to unpack .../081-libvorbisfile3_1.3.7-1_arm64.deb ...
# Unpacking libvorbisfile3:arm64 (1.3.7-1) ...
# Selecting previously unselected package libopenmpt0:arm64.
# Preparing to unpack .../082-libopenmpt0_0.6.9-1_arm64.deb ...
# Unpacking libopenmpt0:arm64 (0.6.9-1) ...
# Selecting previously unselected package librabbitmq4:arm64.
# Preparing to unpack .../083-librabbitmq4_0.11.0-1+b1_arm64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking librabbitmq4:arm64 (0.11.0-1+b1) ...
# Selecting previously unselected package libcjson1:arm64.
# Preparing to unpack .../084-libcjson1_1.7.15-1+deb12u2_arm64.deb ...
# Unpacking libcjson1:arm64 (1.7.15-1+deb12u2) ...
# Selecting previously unselected package libmbedcrypto7:arm64.
# Preparing to unpack .../085-libmbedcrypto7_2.28.3-1_arm64.deb ...
# Unpacking libmbedcrypto7:arm64 (2.28.3-1) ...
# Selecting previously unselected package librist4:arm64.
# Preparing to unpack .../086-librist4_0.2.7+dfsg-1_arm64.deb ...
# Unpacking librist4:arm64 (0.2.7+dfsg-1) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libsrt1.5-gnutls:arm64.
# Preparing to unpack .../087-libsrt1.5-gnutls_1.5.1-1_arm64.deb ...
# Unpacking libsrt1.5-gnutls:arm64 (1.5.1-1) ...
# Selecting previously unselected package libssh-gcrypt-4:arm64.
# Preparing to unpack .../088-libssh-gcrypt-4_0.10.6-0+deb12u1_arm64.deb ...
# Unpacking libssh-gcrypt-4:arm64 (0.10.6-0+deb12u1) ...
# Selecting previously unselected package libnorm1:arm64.
# Preparing to unpack .../089-libnorm1_1.5.9+dfsg-2_arm64.deb ...
# Unpacking libnorm1:arm64 (1.5.9+dfsg-2) ...
# Selecting previously unselected package libpgm-5.3-0:arm64.
# Preparing to unpack .../090-libpgm-5.3-0_5.3.128~dfsg-2_arm64.deb ...
# Unpacking libpgm-5.3-0:arm64 (5.3.128~dfsg-2) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libsodium23:arm64.
# Preparing to unpack .../091-libsodium23_1.0.18-1_arm64.deb ...
# Unpacking libsodium23:arm64 (1.0.18-1) ...
# Selecting previously unselected package libzmq5:arm64.
# Preparing to unpack .../092-libzmq5_4.3.4-6_arm64.deb ...
# Unpacking libzmq5:arm64 (4.3.4-6) ...
# Selecting previously unselected package libavformat59:arm64.
# Preparing to unpack .../093-libavformat59_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libavformat59:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libbs2b0:arm64.
# Preparing to unpack .../094-libbs2b0_3.1.0+dfsg-7_arm64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libbs2b0:arm64 (3.1.0+dfsg-7) ...
# Selecting previously unselected package libflite1:arm64.
# Preparing to unpack .../095-libflite1_2.2-5_arm64.deb ...
# Unpacking libflite1:arm64 (2.2-5) ...
# Selecting previously unselected package libserd-0-0:arm64.
# Preparing to unpack .../096-libserd-0-0_0.30.16-1_arm64.deb ...
# Unpacking libserd-0-0:arm64 (0.30.16-1) ...
# Selecting previously unselected package libsord-0-0:arm64.
# Preparing to unpack .../097-libsord-0-0_0.16.14+git221008-1_arm64.deb ...
# Unpacking libsord-0-0:arm64 (0.16.14+git221008-1) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libsratom-0-0:arm64.
# Preparing to unpack .../098-libsratom-0-0_0.6.14-1_arm64.deb ...
# Unpacking libsratom-0-0:arm64 (0.6.14-1) ...
# Selecting previously unselected package liblilv-0-0:arm64.
# Preparing to unpack .../099-liblilv-0-0_0.24.14-1_arm64.deb ...
# Unpacking liblilv-0-0:arm64 (0.24.14-1) ...
# Selecting previously unselected package libmysofa1:arm64.
# Preparing to unpack .../100-libmysofa1_1.3.1~dfsg0-1_arm64.deb ...
# Unpacking libmysofa1:arm64 (1.3.1~dfsg0-1) ...
# Selecting previously unselected package libepoxy0:arm64.
# Preparing to unpack .../101-libepoxy0_1.5.10-1_arm64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libepoxy0:arm64 (1.5.10-1) ...
# Selecting previously unselected package libvulkan1:arm64.
# Preparing to unpack .../102-libvulkan1_1.3.239.0-1_arm64.deb ...
# Unpacking libvulkan1:arm64 (1.3.239.0-1) ...
# Selecting previously unselected package libplacebo208:arm64.
# Preparing to unpack .../103-libplacebo208_4.208.0-3_arm64.deb ...
# Unpacking libplacebo208:arm64 (4.208.0-3) ...
# Selecting previously unselected package libblas3:arm64.
# Preparing to unpack .../104-libblas3_3.11.0-2_arm64.deb ...
# Unpacking libblas3:arm64 (3.11.0-2) ...
# Selecting previously unselected package libgfortran5:arm64.
# Preparing to unpack .../105-libgfortran5_12.2.0-14_arm64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libgfortran5:arm64 (12.2.0-14) ...
# Selecting previously unselected package liblapack3:arm64.
# Preparing to unpack .../106-liblapack3_3.11.0-2_arm64.deb ...
# Unpacking liblapack3:arm64 (3.11.0-2) ...
# Selecting previously unselected package libasyncns0:arm64.
# Preparing to unpack .../107-libasyncns0_0.8-6+b3_arm64.deb ...
# Unpacking libasyncns0:arm64 (0.8-6+b3) ...
# Selecting previously unselected package libflac12:arm64.
# Preparing to unpack .../108-libflac12_1.4.2+ds-2_arm64.deb ...
# Unpacking libflac12:arm64 (1.4.2+ds-2) ...
# 7Progress: [ 30%] [#################.........................................] 8Selecting previously unselected package libsndfile1:arm64.
# Preparing to unpack .../109-libsndfile1_1.2.0-1_arm64.deb ...
# Unpacking libsndfile1:arm64 (1.2.0-1) ...
# Selecting previously unselected package libpulse0:arm64.
# Preparing to unpack .../110-libpulse0_16.1+dfsg1-2+b1_arm64.deb ...
# Unpacking libpulse0:arm64 (16.1+dfsg1-2+b1) ...
# Selecting previously unselected package libsphinxbase3:arm64.
# Preparing to unpack .../111-libsphinxbase3_0.8+5prealpha+1-16_arm64.deb ...
# Unpacking libsphinxbase3:arm64 (0.8+5prealpha+1-16) ...
# Selecting previously unselected package libpocketsphinx3:arm64.
# Preparing to unpack .../112-libpocketsphinx3_0.8+5prealpha+1-15_arm64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking libpocketsphinx3:arm64 (0.8+5prealpha+1-15) ...
# Selecting previously unselected package libpostproc56:arm64.
# Preparing to unpack .../113-libpostproc56_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libpostproc56:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package librubberband2:arm64.
# Preparing to unpack .../114-librubberband2_3.1.2+dfsg0-1_arm64.deb ...
# Unpacking librubberband2:arm64 (3.1.2+dfsg0-1) ...
# Selecting previously unselected package libswscale6:arm64.
# Preparing to unpack .../115-libswscale6_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libswscale6:arm64 (7:5.1.6-0+deb12u1) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libvidstab1.1:arm64.
# Preparing to unpack .../116-libvidstab1.1_1.1.0-2+b1_arm64.deb ...
# Unpacking libvidstab1.1:arm64 (1.1.0-2+b1) ...
# Selecting previously unselected package libzimg2:arm64.
# Preparing to unpack .../117-libzimg2_3.0.4+ds1-1_arm64.deb ...
# Unpacking libzimg2:arm64 (3.0.4+ds1-1) ...
# Selecting previously unselected package libavfilter8:arm64.
# Preparing to unpack .../118-libavfilter8_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libavfilter8:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libslang2:arm64.
# Preparing to unpack .../119-libslang2_2.3.3-3_arm64.deb ...
# Unpacking libslang2:arm64 (2.3.3-3) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libcaca0:arm64.
# Preparing to unpack .../120-libcaca0_0.99.beta20-3_arm64.deb ...
# Unpacking libcaca0:arm64 (0.99.beta20-3) ...
# Selecting previously unselected package libcdio19:arm64.
# Preparing to unpack .../121-libcdio19_2.1.0-4_arm64.deb ...
# Unpacking libcdio19:arm64 (2.1.0-4) ...
# Selecting previously unselected package libcdio-cdda2:arm64.
# Preparing to unpack .../122-libcdio-cdda2_10.2+2.0.1-1_arm64.deb ...
# Unpacking libcdio-cdda2:arm64 (10.2+2.0.1-1) ...
# Selecting previously unselected package libcdio-paranoia2:arm64.
# Preparing to unpack .../123-libcdio-paranoia2_10.2+2.0.1-1_arm64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libcdio-paranoia2:arm64 (10.2+2.0.1-1) ...
# ...
# Preparing to unpack .../167-libavdevice59_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking libavdevice59:arm64 (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package ffmpeg.
# Preparing to unpack .../168-ffmpeg_7%3a5.1.6-0+deb12u1_arm64.deb ...
# Unpacking ffmpeg (7:5.1.6-0+deb12u1) ...
# Selecting previously unselected package libaacs0:arm64.
# Preparing to unpack .../169-libaacs0_0.11.1-2_arm64.deb ...
# Unpacking libaacs0:arm64 (0.11.1-2) ...
# Selecting previously unselected package libbdplus0:arm64.
# Preparing to unpack .../170-libbdplus0_0.2.0-3_arm64.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking libbdplus0:arm64 (0.2.0-3) ...
# Selecting previously unselected package libdecor-0-plugin-1-cairo:arm64.
# Preparing to unpack .../171-libdecor-0-plugin-1-cairo_0.1.1-2_arm64.deb ...
# Unpacking libdecor-0-plugin-1-cairo:arm64 (0.1.1-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../172-libgdk-pixbuf2.0-bin_2.42.10+dfsg-1+deb12u1_arm64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.42.10+dfsg-1+deb12u1) ...
# Selecting previously unselected package librsvg2-common:arm64.
# Preparing to unpack .../173-librsvg2-common_2.54.7+dfsg-1~deb12u1_arm64.deb ...
# Unpacking librsvg2-common:arm64 (2.54.7+dfsg-1~deb12u1) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libvdpau-va-gl1:arm64.
# Preparing to unpack .../174-libvdpau-va-gl1_0.4.2-1+b1_arm64.deb ...
# Unpacking libvdpau-va-gl1:arm64 (0.4.2-1+b1) ...
# Selecting previously unselected package mesa-va-drivers:arm64.
# Preparing to unpack .../175-mesa-va-drivers_22.3.6-1+deb12u1_arm64.deb ...
# Unpacking mesa-va-drivers:arm64 (22.3.6-1+deb12u1) ...
# Selecting previously unselected package mesa-vdpau-drivers:arm64.
# Preparing to unpack .../176-mesa-vdpau-drivers_22.3.6-1+deb12u1_arm64.deb ...
# Unpacking mesa-vdpau-drivers:arm64 (22.3.6-1+deb12u1) ...
# Selecting previously unselected package mesa-vulkan-drivers:arm64.
# Preparing to unpack .../177-mesa-vulkan-drivers_22.3.6-1+deb12u1_arm64.deb ...
# Unpacking mesa-vulkan-drivers:arm64 (22.3.6-1+deb12u1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package pocketsphinx-en-us.
# Preparing to unpack .../178-pocketsphinx-en-us_0.8+5prealpha+1-15_all.deb ...
# Unpacking pocketsphinx-en-us (0.8+5prealpha+1-15) ...
# Selecting previously unselected package va-driver-all:arm64.
# Preparing to unpack .../179-va-driver-all_2.17.0-1_arm64.deb ...
# Unpacking va-driver-all:arm64 (2.17.0-1) ...
# Selecting previously unselected package vdpau-driver-all:arm64.
# Preparing to unpack .../180-vdpau-driver-all_1.5-2_arm64.deb ...
# Unpacking vdpau-driver-all:arm64 (1.5-2) ...
# Setting up libgme0:arm64 (0.6.3-6) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up libssh-gcrypt-4:arm64 (0.10.6-0+deb12u1) ...
# Setting up libgraphite2-3:arm64 (1.3.14-1) ...
# Setting up libxcb-dri3-0:arm64 (1.15-1) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up liblcms2-2:arm64 (2.14-2) ...
# Setting up libpixman-1-0:arm64 (0.42.2-1) ...
# Setting up libudfread0:arm64 (1.1.2-1) ...
# Setting up libwayland-server0:arm64 (1.21.0-1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libaom3:arm64 (3.6.0-1+deb12u1) ...
# Setting up libx11-xcb1:arm64 (2:1.8.4-2+deb12u2) ...
# Setting up fontconfig (2.14.1-4) ...
# Regenerating fonts cache... done.
# Setting up librabbitmq4:arm64 (0.11.0-1+b1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libraw1394-11:arm64 (2.1.2-2) ...
# Setting up libapparmor1:arm64 (3.0.8-3) ...
# Setting up libcodec2-1.0:arm64 (1.0.5-1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libsodium23:arm64 (1.0.18-1) ...
# Setting up libmpg123-0:arm64 (1.31.2-1) ...
# Setting up libxcb-xfixes0:arm64 (1.15-1) ...
# Setting up libogg0:arm64 (1.3.5-3) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up liblerc4:arm64 (4.0.0+ds-2) ...
# Setting up libspeex1:arm64 (1.2.1-2) ...
# Setting up libshine3:arm64 (3.1.1-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libxi6:arm64 (2:1.8-1+b1) ...
# Setting up libx264-164:arm64 (2:0.164.3095+gitbaee400-3) ...
# Setting up libtwolame0:arm64 (0.4.0-2) ...
# Setting up libdatrie1:arm64 (0.2.13-2+b1) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libgsm1:arm64 (1.0.22-1) ...
# Setting up libxcb-render0:arm64 (1.15-1) ...
# Setting up libsoxr0:arm64 (0.1.3-4) ...
# Setting up libglvnd0:arm64 (1.6.0-1) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libpgm-5.3-0:arm64 (5.3.128~dfsg-2) ...
# Setting up libxcb-glx0:arm64 (1.15-1) ...
# Setting up libgdk-pixbuf2.0-common (2.42.10+dfsg-1+deb12u1) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libnorm1:arm64 (1.5.9+dfsg-2) ...
# Setting up libmysofa1:arm64 (1.3.1~dfsg0-1) ...
# Setting up libxcb-shape0:arm64 (1.15-1) ...
# Setting up libsensors-config (1:3.6.0-7.1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libdeflate0:arm64 (1.14-1) ...
# Setting up xkb-data (2.35.1-1) ...
# Setting up libhwy1:arm64 (1.0.3-3+deb12u1) ...
# Setting up libxcb-shm0:arm64 (1.15-1) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libsvtav1enc1:arm64 (1.4.1+dfsg-1) ...
# Setting up libcdio19:arm64 (2.1.0-4) ...
# Setting up libcjson1:arm64 (1.7.15-1+deb12u2) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxvidcore4:arm64 (2:1.3.7-1) ...
# Setting up libjbig0:arm64 (2.1-6.1) ...
# Setting up libcairo2:arm64 (1.16.0-7) ...
# Setting up librav1e0:arm64 (0.5.1-6) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libxxf86vm1:arm64 (1:1.1.4-1+b2) ...
# Setting up libsnappy1v5:arm64 (1.1.9-3) ...
# Setting up libxcb-present0:arm64 (1.15-1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libasound2-data (1.2.8-1) ...
# Setting up libz3-4:arm64 (4.8.12-3.1) ...
# Setting up libblas3:arm64 (3.11.0-2) ...
# update-alternatives: using /usr/lib/aarch64-linux-gnu/blas/libblas.so.3 to provide /usr/lib/aarch64-linux-gnu/libblas.so.3 (libblas.so.3-aarch64-linux-gnu) in auto mode
# Setting up libflac12:arm64 (1.4.2+ds-2) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libslang2:arm64 (2.3.3-3) ...
# Setting up libva2:arm64 (2.17.0-1) ...
# Setting up libmbedcrypto7:arm64 (2.28.3-1) ...
# Setting up libepoxy0:arm64 (1.5.10-1) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libxfixes3:arm64 (1:6.0.0-2) ...
# Setting up libxcb-sync1:arm64 (1.15-1) ...
# Setting up libdbus-1-3:arm64 (1.14.10-1~deb12u1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libfribidi0:arm64 (1.0.8-2.1) ...
# Setting up libopus0:arm64 (1.3.1-3) ...
# Setting up libxv1:arm64 (2:1.0.11-1.1) ...
# Setting up libvorbis0a:arm64 (1.3.7-1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libxrandr2:arm64 (2:1.5.2-2+b1) ...
# Setting up libsensors5:arm64 (1:3.6.0-7.1) ...
# Setting up libaacs0:arm64 (0.11.1-2) ...
# Setting up libjxl0.7:arm64 (0.7.0-10) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up pocketsphinx-en-us (0.8+5prealpha+1-15) ...
# Setting up libdav1d6:arm64 (1.0.0-2+deb12u1) ...
# Setting up libglapi-mesa:arm64 (22.3.6-1+deb12u1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libgfortran5:arm64 (12.2.0-14) ...
# Setting up libvulkan1:arm64 (1.3.239.0-1) ...
# Setting up libx265-199:arm64 (3.5-2+b1) ...
# Setting up librubberband2:arm64 (3.1.2+dfsg0-1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libxcb-dri2-0:arm64 (1.15-1) ...
# Setting up libbdplus0:arm64 (0.2.0-3) ...
# Setting up libvidstab1.1:arm64 (1.1.0-2+b1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libsrt1.5-gnutls:arm64 (1.5.1-1) ...
# Setting up alsa-topology-conf (1.2.5.1-2) ...
# Setting up ocl-icd-libopencl1:arm64 (2.3.1-1) ...
# Setting up libasyncns0:arm64 (0.8-6+b3) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libxshmfence1:arm64 (1.3-1) ...
# Setting up libvdpau1:arm64 (1.5-2) ...
# Setting up libtiff6:arm64 (4.5.0-6+deb12u1) ...
# Setting up libbs2b0:arm64 (3.1.0+dfsg-7) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libxcb-randr0:arm64 (1.15-1) ...
# Setting up dbus-session-bus-common (1.14.10-1~deb12u1) ...
# Setting up libllvm15:arm64 (1:15.0.6-4+b1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libtheora0:arm64 (1.1.1+dfsg.1-16.1+b1) ...
# Setting up libasound2:arm64 (1.2.8-1+b1) ...
# Setting up libzimg2:arm64 (3.0.4+ds1-1) ...
# Setting up libopenjp2-7:arm64 (2.5.0-2) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libharfbuzz0b:arm64 (6.0.0+dfsg-3) ...
# Setting up libopenal-data (1:1.19.1-2) ...
# Setting up libthai-data (0.1.29-1) ...
# Setting up libgdk-pixbuf-2.0-0:arm64 (2.42.10+dfsg-1+deb12u1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libvpx7:arm64 (1.12.0-1+deb12u3) ...
# Setting up libcairo-gobject2:arm64 (1.16.0-7) ...
# Setting up libwayland-egl1:arm64 (1.21.0-1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libusb-1.0-0:arm64 (2:1.0.26-1) ...
# Setting up dbus-system-bus-common (1.14.10-1~deb12u1) ...
# Setting up libbluray2:arm64 (1:1.3.4-1) ...
# Setting up libsamplerate0:arm64 (0.2.2-3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libdrm-common (2.4.114-1) ...
# Setting up dbus-bin (1.14.10-1~deb12u1) ...
# Setting up libzvbi-common (0.2.41-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libmp3lame0:arm64 (3.100-6) ...
# Setting up libvorbisenc2:arm64 (1.3.7-1) ...
# Setting up libiec61883-0:arm64 (1.2.0-6+b1) ...
# Setting up libserd-0-0:arm64 (0.30.16-1) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libxkbcommon0:arm64 (1.5.0-1) ...
# Setting up libwayland-client0:arm64 (1.21.0-1) ...
# Setting up libavc1394-0:arm64 (0.5.4-5) ...
# Setting up libzvbi0:arm64 (0.2.41-1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up liblapack3:arm64 (3.11.0-2) ...
# update-alternatives: using /usr/lib/aarch64-linux-gnu/lapack/liblapack.so.3 to provide /usr/lib/aarch64-linux-gnu/liblapack.so.3 (liblapack.so.3-aarch64-linux-gnu) in auto mode
# Setting up libplacebo208:arm64 (4.208.0-3) ...
# Setting up libzmq5:arm64 (4.3.4-6) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libcaca0:arm64 (0.99.beta20-3) ...
# Setting up alsa-ucm-conf (1.2.8-1) ...
# Setting up libcdio-cdda2:arm64 (10.2+2.0.1-1) ...
# Setting up libcdio-paranoia2:arm64 (10.2+2.0.1-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libxcursor1:arm64 (1:1.2.1-1) ...
# Setting up dbus-daemon (1.14.10-1~deb12u1) ...
# Setting up librist4:arm64 (0.2.7+dfsg-1) ...
# Setting up libthai0:arm64 (0.1.29-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libvorbisfile3:arm64 (1.3.7-1) ...
# Setting up libass9:arm64 (1:0.17.1-1) ...
# Setting up dbus (1.14.10-1~deb12u1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# 7Progress: [ 86%] [#################################################.........] 8Setting up libdc1394-25:arm64 (2.2.6-4) ...
# Setting up libsndio7.0:arm64 (1.9.0-0.3+b2) ...
# Setting up libjack-jackd2-0:arm64 (1.9.21~dfsg-3) ...
# Setting up libdrm2:arm64 (2.4.114-1+b1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libflite1:arm64 (2.2-5) ...
# Setting up libva-drm2:arm64 (2.17.0-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.42.10+dfsg-1+deb12u1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libsord-0-0:arm64 (0.16.14+git221008-1) ...
# Setting up libwayland-cursor0:arm64 (1.21.0-1) ...
# Setting up libsratom-0-0:arm64 (0.6.14-1) ...
# Setting up libdecor-0-0:arm64 (0.1.1-2) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libsndfile1:arm64 (1.2.0-1) ...
# Setting up libva-x11-2:arm64 (2.17.0-1) ...
# Setting up liblilv-0-0:arm64 (0.24.14-1) ...
# Setting up libopenmpt0:arm64 (0.6.9-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libdrm-amdgpu1:arm64 (2.4.114-1+b1) ...
# Setting up mesa-vulkan-drivers:arm64 (22.3.6-1+deb12u1) ...
# Setting up libdrm-nouveau2:arm64 (2.4.114-1+b1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libgbm1:arm64 (22.3.6-1+deb12u1) ...
# Setting up libpulse0:arm64 (16.1+dfsg1-2+b1) ...
# Setting up libdrm-radeon1:arm64 (2.4.114-1+b1) ...
# Setting up libpango-1.0-0:arm64 (1.50.12+ds-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libgl1-mesa-dri:arm64 (22.3.6-1+deb12u1) ...
# Setting up libopenal1:arm64 (1:1.19.1-2) ...
# Setting up libavutil57:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up libswresample4:arm64 (7:5.1.6-0+deb12u1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libpostproc56:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up mesa-va-drivers:arm64 (22.3.6-1+deb12u1) ...
# Setting up libpangoft2-1.0-0:arm64 (1.50.12+ds-1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libsdl2-2.0-0:arm64 (2.26.5+dfsg-1) ...
# Setting up libswscale6:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up libpangocairo-1.0-0:arm64 (1.50.12+ds-1) ...
# Setting up mesa-vdpau-drivers:arm64 (22.3.6-1+deb12u1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libglx-mesa0:arm64 (22.3.6-1+deb12u1) ...
# Setting up libglx0:arm64 (1.6.0-1) ...
# Setting up libsphinxbase3:arm64 (0.8+5prealpha+1-16) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up librsvg2-2:arm64 (2.54.7+dfsg-1~deb12u1) ...
# Setting up libpocketsphinx3:arm64 (0.8+5prealpha+1-15) ...
# Setting up libgl1:arm64 (1.6.0-1) ...
# Setting up va-driver-all:arm64 (2.17.0-1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libdecor-0-plugin-1-cairo:arm64 (0.1.1-2) ...
# Setting up librsvg2-common:arm64 (2.54.7+dfsg-1~deb12u1) ...
# Setting up libavcodec59:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up libvdpau-va-gl1:arm64 (0.4.2-1+b1) ...
# Setting up libchromaprint1:arm64 (1.5.1-2+b1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavformat59:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up libavfilter8:arm64 (7:5.1.6-0+deb12u1) ...
# Setting up libavdevice59:arm64 (7:5.1.6-0+deb12u1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up vdpau-driver-all:arm64 (1.5-2) ...
# Setting up ffmpeg (7:5.1.6-0+deb12u1) ...
# Processing triggers for man-db (2.11.2-2) ...
# Processing triggers for libc-bin (2.36-9+deb12u8) ...
# Processing triggers for libgdk-pixbuf-2.0-0:arm64 (2.42.10+dfsg-1+deb12u1) ...
#
# 78

# %%
# !pip uninstall -q -y opencv-python-headless
# !pip install -q "opencv-python-headless<4.3"
# Out:
# WARNING: Skipping opencv-python-headless as it is not installed.
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import libraries
import pathlib

import matplotlib as mpl
import matplotlib.pyplot as plt
import mediapy as media
import numpy as np
import PIL

import tensorflow as tf
import tensorflow_hub as hub
import tqdm

mpl.rcParams.update({
    'font.size': 10,
})

# %% [markdown]
# Get the kinetics 600 label list, and print the first few labels:

# %%
labels_path = tf.keras.utils.get_file(
    fname='labels.txt',
    origin='https://raw.githubusercontent.com/tensorflow/models/f8af2291cced43fc9f1d9b41ddbf772ae7b0d7d2/official/projects/movinet/files/kinetics_600_labels.txt'
)
labels_path = pathlib.Path(labels_path)

lines = labels_path.read_text().splitlines()
KINETICS_600_LABELS = np.array([line.strip() for line in lines])
KINETICS_600_LABELS[:20]
# Out:
# Downloading data from https://raw.githubusercontent.com/tensorflow/models/f8af2291cced43fc9f1d9b41ddbf772ae7b0d7d2/official/projects/movinet/files/kinetics_600_labels.txt
# 9209/9209 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# array(['abseiling', 'acting in play', 'adjusting glasses', 'air drumming',
#        'alligator wrestling', 'answering questions', 'applauding',
#        'applying cream', 'archaeological excavation', 'archery',
#        'arguing', 'arm wrestling', 'arranging flowers',
#        'assembling bicycle', 'assembling computer',
#        'attending conference', 'auctioning', 'backflip (human)',
#        'baking cookies', 'bandaging'], dtype='<U49')

# %% [markdown]
# Define a function to read an mp4 file into a `tf.Tensor`:

# %%
import cv2
import tensorflow as tf

def load_mp4(file_path, image_size=(224, 224)):
    """Loads an mp4 file into a TF tensor.

    Args:
        file_path: path to the location of an mp4 file.
        image_size: a tuple of target size.

    Returns:
        a video tensor of the mp4 file
    """
    # Open the video file
    cap = cv2.VideoCapture(file_path)
    frames = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        # Resize the frame
        frame = cv2.resize(frame, image_size)
        # Convert the frame to RGB (OpenCV uses BGR by default)
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Append the frame to the list
        frames.append(frame)

    cap.release()



    # Convert the list of frames to a TF tensor
    video = tf.convert_to_tensor(frames, dtype=tf.float32)
    # Normalize the video to [0, 1]
    video = video / 255.0
    return video

# %% [markdown]
# The video's shape is `(frames, height, width, colors)`

# %%
clapping=load_mp4("Clapping.mp4")
clapping.shape
# Out:
# TensorShape([307, 224, 224, 3])

# %% [markdown]
# ## How to use the model
#
# This section contains a walkthrough showing how to use the [models from TensorFlow Hub](https://tfhub.dev/google/collections/movinet/1). If you just want to see the models in action, skip to the next section.
#
# There are two versions of each model: `base` and `streaming`.
#
# * The `base` version takes a video as input, and returns the probabilities averaged over the frames.
# * The `streaming` version takes a video frame and an RNN state as input, and returns the predictions for that frame, and the new RNN state.

# %% [markdown]
# ### The base model

# %% [markdown]
# Download the [pretrained model from TensorFlow Hub](https://tfhub.dev/tensorflow/movinet/a2/base/kinetics-600/classification/3).

# %%
# %%time
id = 'a2'
mode = 'base'
version = '3'
hub_url = f'https://tfhub.dev/tensorflow/movinet/{id}/{mode}/kinetics-600/classification/{version}'
model = hub.load(hub_url)
# Out:
# CPU times: user 7.87 s, sys: 289 ms, total: 8.16 s
# Wall time: 10.4 s

# %% [markdown]
# This version of the model has one `signature`. It takes an `image` argument which is a `tf.float32` with shape `(batch, frames, height, width, colors)`. It returns a dictionary containing one output: A `tf.float32` tensor of logits with shape `(batch, classes)`.

# %%
sig = model.signatures['serving_default']
print(sig.pretty_printed_signature())
# Out:
# Input Parameters:
#   image (KEYWORD_ONLY): TensorSpec(shape=(None, None, None, None, 3), dtype=tf.float32, name='image')
# Output Type:
#   Dict[['classifier_head', TensorSpec(shape=(None, 600), dtype=tf.float32, name='classifier_head')]]
# Captures:
#   281470768561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257717296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257717120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768561520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257716416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768561696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768561168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768561344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257714832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257714656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257715184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767943168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767944752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767945104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768560112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257714128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257714480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257714304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768559760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257713072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257712368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257711840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257711312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257711136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257711664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257711488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768557824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768557648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768557472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768557296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257710080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768557120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257709376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257708320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257708848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257708672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768556064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767940704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767942288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767943344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767942640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768554832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257708144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768554656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257706912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257707264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768554480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262588448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257706736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257706560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262588624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768555008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768554304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262588272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262588096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262587568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262586512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262586336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262586864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262586688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768553072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262586160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262585104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768551840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768552544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768551664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768551488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262583696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262583520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262584048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262583872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768551312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262583344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262583168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768551136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262582112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768550080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262581056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768549728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262580176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768548672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768548848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767941936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767938048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767941056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767940352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768548496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262579648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262579472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262579296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262579824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768548320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262579120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768548144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262578064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768547088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262576832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262576656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262576480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262577008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768546736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262576304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262576128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768545856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257640656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262575424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257640480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257640128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257640304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262573840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262573664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262574192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262572960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262573488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262573312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257639072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262490144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262572784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262572608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262490320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257638016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262489264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262488384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257637840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257637664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257637488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257637312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262487856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262487680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262487504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262487328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257637136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262487152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262486448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257636080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257635024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262484512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262485040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262484864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257634848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262484336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262484160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257634144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257634496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257634320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257634672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262483632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262481696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262482048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257633264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262481520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262481344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262481168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257632032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262480112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257631680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257631504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257631328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257631152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257631856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262477824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262477648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262477472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262478000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257630448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262477296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262477120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262476416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257628864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257628688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257628512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257628336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257629040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262474832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262474656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262475184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257628160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767938224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767934528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767935584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791417376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262474480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471262474304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791417552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791417200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791417024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791416848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791416672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257627456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791416320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791416144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791416496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791415088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791414912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791414736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791414384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257625872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257625696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257625520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257625344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257626048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791414032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791413680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791413328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791412976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257625168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257722048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791412272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791411920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791411568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791412624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791410512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791410160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791411216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791410864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257624816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257624640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257722576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257722400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257624992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791409808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791409456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791409104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791408752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257722224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257721696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791408400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791408048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791407696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791407344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257721520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791406640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791405936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791406992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257721344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791404528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791405584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791405232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791404880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791403120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791404176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791403824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791403472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257720112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791402768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791402416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791402064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470791401712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768119152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768118800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768118448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257719056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768117040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768117744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768116688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768115808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768116160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768115104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257717824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257718528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768106304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471853957312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767950912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767951440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257717648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281471257717472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767949856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767947392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470767950560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768693840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768693664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768693488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   281470768693312: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# To run this signature on the video you need to add the outer `batch` dimension to the video first.

# %%
#warmup
sig(image = clapping[tf.newaxis, :1]);

# %%
# %%time
logits = sig(image = clapping[tf.newaxis, ...])
logits = logits['classifier_head'][0]

print(logits.shape)
print()
# Out:
# (600,)
#
# CPU times: user 15min 45s, sys: 15.4 s, total: 16min 1s
# Wall time: 2min 32s

# %% [markdown]
# Define a `get_top_k` function that packages the above output processing for later.

# %%
#@title
# Get top_k labels and probabilities
def get_top_k(probs, k=5, label_map=KINETICS_600_LABELS):
  """Outputs the top k model labels and probabilities on the given video.

  Args:
    probs: probability tensor of shape (num_frames, num_classes) that represents
      the probability of each class on each frame.
    k: the number of top predictions to select.
    label_map: a list of labels to map logit indices to label strings.

  Returns:
    a tuple of the top-k labels and probabilities.
  """
  # Sort predictions to find top_k
  top_predictions = tf.argsort(probs, axis=-1, direction='DESCENDING')[:k]
  # collect the labels of top_k predictions
  top_labels = tf.gather(label_map, top_predictions, axis=-1)
  # decode lablels
  top_labels = [label.decode('utf8') for label in top_labels.numpy()]
  # top_k probabilities of the predictions
  top_probs = tf.gather(probs, top_predictions, axis=-1).numpy()
  return tuple(zip(top_labels, top_probs))

# %% [markdown]
# Convert the `logits` to probabilities, and look up the top 5 classes for the video. The model confirms that the video is probably of `jumping jacks`.

# %%
probs = tf.nn.softmax(logits, axis=-1)
for label, p in get_top_k(probs):
  print(f'{label:20s}: {p:.3f}')
# Out:
# stretching arm      : 0.300
# playing darts       : 0.077
# playing harp        : 0.035
# finger snapping     : 0.031
# tai chi             : 0.025

# %% [markdown]
# ### The streaming model

# %% [markdown]
# The previous section used a model that runs over a whole video. Often when processing a video you don't want a single prediction at the end, you want to update predictions frame by frame. The `stream` versions of the model allow you to do this.
#
# Load the `stream` version of the model.

# %%
# %%time
id = 'a2'
mode = 'stream'
version = '3'
hub_url = f'https://tfhub.dev/tensorflow/movinet/{id}/{mode}/kinetics-600/classification/{version}'
model = hub.load(hub_url)
# Out:
# WARNING:absl:`state/b0/l2/pool_buffer` is not a valid tf.function parameter name. Sanitizing to `state_b0_l2_pool_buffer`.
# WARNING:absl:`state/b1/l0/pool_frame_count` is not a valid tf.function parameter name. Sanitizing to `state_b1_l0_pool_frame_count`.
# WARNING:absl:`state/b2/l1/stream_buffer` is not a valid tf.function parameter name. Sanitizing to `state_b2_l1_stream_buffer`.
# WARNING:absl:`state/b0/l1/pool_buffer` is not a valid tf.function parameter name. Sanitizing to `state_b0_l1_pool_buffer`.
# WARNING:absl:`state/b4/l0/pool_buffer` is not a valid tf.function parameter name. Sanitizing to `state_b4_l0_pool_buffer`.
# CPU times: user 24 s, sys: 811 ms, total: 24.8 s
# Wall time: 27.3 s

# %%
# Define the path where you want to save the model
save_path = 'saved_model'

# Save the model
tf.saved_model.save(model, save_path)

print(f'Model saved to {save_path}')
# Out:
# INFO:tensorflow:Assets written to: saved_model/assets
# INFO:tensorflow:Assets written to: saved_model/assets
# Model saved to saved_model

# %% [markdown]
# Using this model is slightly more complex than the `base` model. You have to keep track of the internal state of the model's RNNs.

# %%
list(model.signatures.keys())
# Out:
# ['call', 'init_states']

# %% [markdown]
# The `init_states` signature takes the video's **shape** `(batch, frames, height, width, colors)` as input, and returns a large dictionary of tensors containing the initial RNN states:

# %%
lines = model.signatures['init_states'].pretty_printed_signature().splitlines()
lines = lines[:10]
lines.append('      ...')
print('.\n'.join(lines))
# Out:
# Input Parameters:.
#   input_shape (KEYWORD_ONLY): TensorSpec(shape=(5,), dtype=tf.int32, name='input_shape').
# Output Type:.
#   Dict[['state/b4/l0/stream_buffer', TensorSpec(shape=(None, 4, None, None, 480), dtype=tf.float32, name='state/b4/l0/stream_buffer')], ['state/b2/l0/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 240), dtype=tf.float32, name='state/b2/l0/pool_buffer')], ['state/b3/l1/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b3/l1/pool_frame_count')], ['state/b4/l0/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b4/l0/pool_frame_count')], ['state/b0/l0/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b0/l0/pool_frame_count')], ['state/b2/l1/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b2/l1/pool_frame_count')], ['state/b2/l1/stream_buffer', TensorSpec(shape=(None, 2, None, None, 160), dtype=tf.float32, name='state/b2/l1/stream_buffer')], ['state/b4/l6/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b4/l6/pool_frame_count')], ['state/b2/l3/stream_buffer', TensorSpec(shape=(None, 2, None, None, 192), dtype=tf.float32, name='state/b2/l3/stream_buffer')], ['state/b1/l2/stream_buffer', TensorSpec(shape=(None, 2, None, None, 96), dtype=tf.float32, name='state/b1/l2/stream_buffer')], ['state/b0/l1/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b0/l1/pool_frame_count')], ['state/b4/l5/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 480), dtype=tf.float32, name='state/b4/l5/pool_buffer')], ['state/b1/l0/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 96), dtype=tf.float32, name='state/b1/l0/pool_buffer')], ['state/b3/l4/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 144), dtype=tf.float32, name='state/b3/l4/pool_buffer')], ['state/b1/l4/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b1/l4/pool_frame_count')], ['state/b4/l2/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b4/l2/pool_frame_count')], ['state/b3/l5/stream_buffer', TensorSpec(shape=(None, 2, None, None, 240), dtype=tf.float32, name='state/b3/l5/stream_buffer')], ['state/b3/l1/stream_buffer', TensorSpec(shape=(None, 2, None, None, 240), dtype=tf.float32, name='state/b3/l1/stream_buffer')], ['state/b2/l2/stream_buffer', TensorSpec(shape=(None, 2, None, None, 240), dtype=tf.float32, name='state/b2/l2/stream_buffer')], ['state/head/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/head/pool_frame_count')], ['state/b0/l2/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b0/l2/pool_frame_count')], ['state/b4/l4/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b4/l4/pool_frame_count')], ['state/b1/l4/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 120), dtype=tf.float32, name='state/b1/l4/pool_buffer')], ['state/b0/l2/stream_buffer', TensorSpec(shape=(None, 2, None, None, 64), dtype=tf.float32, name='state/b0/l2/stream_buffer')], ['state/b4/l1/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b4/l1/pool_frame_count')], ['state/b1/l1/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 120), dtype=tf.float32, name='state/b1/l1/pool_buffer')], ['state/b2/l3/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b2/l3/pool_frame_count')], ['state/b1/l2/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b1/l2/pool_frame_count')], ['state/b1/l3/pool_frame_count', TensorSpec(shape=(1,), dtype=tf.int32, name='state/b1/l3/pool_frame_count')], ['state/b4/l2/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 384), dtype=tf.float32, name='state/b4/l2/pool_buffer')], ['state/b1/l0/stream_buffer', TensorSpec(shape=(None, 2, None, None, 96), dtype=tf.float32, name='state/b1/l0/stream_buffer')], ['state/b1/l3/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 96), dtype=tf.float32, name='state/b1/l3/pool_buffer')], ['state/b3/l1/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 240), dtype=tf.float32, name='state/b3/l1/pool_buffer')], ['state/b0/l1/pool_buffer', TensorSpec(shape=(None, 1, 1, 1, 40), dtype=tf.float32, name='state/b0/l1/p ...
# Captures:.
#   None.
#       ...

# %%
initial_state = model.init_states(clapping[tf.newaxis, ...].shape)

# %%
type(initial_state)
# Out:
# dict

# %%
list(sorted(initial_state.keys()))[:5]
# Out:
# ['state/b0/l0/pool_buffer',
#  'state/b0/l0/pool_frame_count',
#  'state/b0/l1/pool_buffer',
#  'state/b0/l1/pool_frame_count',
#  'state/b0/l1/stream_buffer']

# %% [markdown]
# Once you have the initial state for the RNNs, you can pass the state and a video frame as input (keeping the `(batch, frames, height, width, colors)` shape for the video frame). The model returns a `(logits, state)` pair.
#
# After just seeing the first frame, the model is not convinced that the video is of "jumping jacks":

# %%
inputs = initial_state.copy()

# Add the batch axis, take the first frme, but keep the frame-axis.
inputs['image'] = clapping[tf.newaxis, 0:1, ...]

# %%
# warmup
model(inputs);

# %%
logits, new_state = model(inputs)
logits = logits[0]
probs = tf.nn.softmax(logits, axis=-1)

for label, p in get_top_k(probs):
  print(f'{label:20s}: {p:.3f}')

print()
# Out:
# opening door        : 0.587
# laying tiles        : 0.039
# tiptoeing           : 0.030
# mopping floor       : 0.023
# opening wine bottle : 0.021

# %% [markdown]
# If you run the model in a loop, passing the updated state with each frame, the model quickly converges to the correct result:

# %%
# %%time
state = initial_state.copy()
all_logits = []

for n in range(len(clapping)):
  inputs = state
  inputs['image'] = clapping[tf.newaxis, n:n+1, ...]
  result, state = model(inputs)
  all_logits.append(logits)

probabilities = tf.nn.softmax(all_logits, axis=-1)
# Out:
# CPU times: user 35.8 s, sys: 4.61 s, total: 40.4 s
# Wall time: 18.2 s

# %%
for label, p in get_top_k(probabilities[-1]):
  print(f'{label:20s}: {p:.3f}')
# Out:
# opening door        : 0.587
# laying tiles        : 0.039
# tiptoeing           : 0.030
# mopping floor       : 0.023
# opening wine bottle : 0.021

# %%
id = tf.argmax(probabilities[-1])
plt.plot(probabilities[:, id])
plt.xlabel('Frame #')
plt.ylabel(f"p('{KINETICS_600_LABELS[id]}')");

# %% [markdown]
# You may notice that the final probability is much more certain than in the previous section where you ran the `base` model. The `base` model returns an average of the predictions over the frames.

# %%
for label, p in get_top_k(tf.reduce_mean(probabilities, axis=0)):
  print(f'{label:20s}: {p:.3f}')
# Out:
# opening door        : 0.587
# laying tiles        : 0.039
# tiptoeing           : 0.030
# mopping floor       : 0.023
# opening wine bottle : 0.021

# %% [markdown]
# ## Animate the predictions over time
#
# The previous section went into some details about how to use these models. This section builds on top of that to produce some nice inference animations.

# %% [markdown]
# The hidden cell below to defines helper functions used in this section.

# %%
#@title
# Get top_k labels and probabilities predicted using MoViNets streaming model
def get_top_k_streaming_labels(probs, k=5, label_map=KINETICS_600_LABELS):
  """Returns the top-k labels over an entire video sequence.

  Args:
    probs: probability tensor of shape (num_frames, num_classes) that represents
      the probability of each class on each frame.
    k: the number of top predictions to select.
    label_map: a list of labels to map logit indices to label strings.

  Returns:
    a tuple of the top-k probabilities, labels, and logit indices
  """
  top_categories_last = tf.argsort(probs, -1, 'DESCENDING')[-1, :1]
  # Sort predictions to find top_k
  categories = tf.argsort(probs, -1, 'DESCENDING')[:, :k]
  categories = tf.reshape(categories, [-1])

  counts = sorted([
      (i.numpy(), tf.reduce_sum(tf.cast(categories == i, tf.int32)).numpy())
      for i in tf.unique(categories)[0]
  ], key=lambda x: x[1], reverse=True)

  top_probs_idx = tf.constant([i for i, _ in counts[:k]])
  top_probs_idx = tf.concat([top_categories_last, top_probs_idx], 0)
  # find unique indices of categories
  top_probs_idx = tf.unique(top_probs_idx)[0][:k+1]
  # top_k probabilities of the predictions
  top_probs = tf.gather(probs, top_probs_idx, axis=-1)
  top_probs = tf.transpose(top_probs, perm=(1, 0))
  # collect the labels of top_k predictions
  top_labels = tf.gather(label_map, top_probs_idx, axis=0)
  # decode the top_k labels
  top_labels = [label.decode('utf8') for label in top_labels.numpy()]

  return top_probs, top_labels, top_probs_idx

# Plot top_k predictions at a given time step
def plot_streaming_top_preds_at_step(
    top_probs,
    top_labels,
    step=None,
    image=None,
    legend_loc='lower left',
    duration_seconds=10,
    figure_height=500,
    playhead_scale=0.8,
    grid_alpha=0.3):
  """Generates a plot of the top video model predictions at a given time step.

  Args:
    top_probs: a tensor of shape (k, num_frames) representing the top-k
      probabilities over all frames.
    top_labels: a list of length k that represents the top-k label strings.
    step: the current time step in the range [0, num_frames].
    image: the image frame to display at the current time step.
    legend_loc: the placement location of the legend.
    duration_seconds: the total duration of the video.
    figure_height: the output figure height.
    playhead_scale: scale value for the playhead.
    grid_alpha: alpha value for the gridlines.

  Returns:
    A tuple of the output numpy image, figure, and axes.
  """
  # find number of top_k labels and frames in the video
  num_labels, num_frames = top_probs.shape
  if step is None:
    step = num_frames
  # Visualize frames and top_k probabilities of streaming video
  fig = plt.figure(figsize=(6.5, 7), dpi=300)
  gs = mpl.gridspec.GridSpec(8, 1)
  ax2 = plt.subplot(gs[:-3, :])
  ax = plt.subplot(gs[-3:, :])
  # display the frame
  if image is not None:
    ax2.imshow(image, interpolation='nearest')
    ax2.axis('off')
  # x-axis (frame number)
  preview_line_x = tf.linspace(0., duration_seconds, num_frames)
  # y-axis (top_k probabilities)
  preview_line_y = top_probs

  line_x = preview_line_x[:step+1]
  line_y = preview_line_y[:, :step+1]

  for i in range(num_labels):
    ax.plot(preview_line_x, preview_line_y[i], label=None, linewidth='1.5',
            linestyle=':', color='gray')
    ax.plot(line_x, line_y[i], label=top_labels[i], linewidth='2.0')


  ax.grid(which='major', linestyle=':', linewidth='1.0', alpha=grid_alpha)
  ax.grid(which='minor', linestyle=':', linewidth='0.5', alpha=grid_alpha)

  min_height = tf.reduce_min(top_probs) * playhead_scale
  max_height = tf.reduce_max(top_probs)
  ax.vlines(preview_line_x[step], min_height, max_height, colors='red')
  ax.scatter(preview_line_x[step], max_height, color='red')

  ax.legend(loc=legend_loc)

  plt.xlim(0, duration_seconds)
  plt.ylabel('Probability')
  plt.xlabel('Time (s)')
  plt.yscale('log')

  fig.tight_layout()
  fig.canvas.draw()

  data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
  data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
  plt.close()

  figure_width = int(figure_height * data.shape[1] / data.shape[0])
  image = PIL.Image.fromarray(data).resize([figure_width, figure_height])
  image = np.array(image)

  return image

# Plotting top_k predictions from MoViNets streaming model
def plot_streaming_top_preds(
    probs,
    video,
    top_k=5,
    video_fps=25.,
    figure_height=500,
    use_progbar=True):
  """Generates a video plot of the top video model predictions.

  Args:
    probs: probability tensor of shape (num_frames, num_classes) that represents
      the probability of each class on each frame.
    video: the video to display in the plot.
    top_k: the number of top predictions to select.
    video_fps: the input video fps.
    figure_fps: the output video fps.
    figure_height: the height of the output video.
    use_progbar: display a progress bar.

  Returns:
    A numpy array representing the output video.
  """
  # select number of frames per second
  video_fps = 8.
  # select height of the image
  figure_height = 500
  # number of time steps of the given video
  steps = video.shape[0]
  # estimate duration of the video (in seconds)
  duration = steps / video_fps
  # estimate top_k probabilities and corresponding labels
  top_probs, top_labels, _ = get_top_k_streaming_labels(probs, k=top_k)

  images = []
  step_generator = tqdm.trange(steps) if use_progbar else range(steps)
  for i in step_generator:
    image = plot_streaming_top_preds_at_step(
        top_probs=top_probs,
        top_labels=top_labels,
        step=i,
        image=video[i],
        duration_seconds=duration,
        figure_height=figure_height,
    )
    images.append(image)

  return np.array(images)

# %% [markdown]
# Start by running the streaming model across the frames of the video, and collecting the logits:

# %%
init_states = model.init_states(clapping[tf.newaxis].shape)

# %%
# Insert your video clip here
video = clapping
images = tf.split(video[tf.newaxis], video.shape[0], axis=1)

all_logits = []

# To run on a video, pass in one frame at a time
states = init_states
for image in tqdm.tqdm(images):
  # predictions for each frame
  logits, states = model({**states, 'image': image})
  all_logits.append(logits)

# concatenating all the logits
logits = tf.concat(all_logits, 0)
# estimating probabilities
probs = tf.nn.softmax(logits, axis=-1)
# Out:
# 100%|██████████| 307/307 [00:18<00:00, 16.82it/s]

# %%
final_probs = probs[-1]
print('Top_k predictions and their probablities\n')
for label, p in get_top_k(final_probs):
  print(f'{label:20s}: {p:.3f}')
# Out:
# Top_k predictions and their probablities
#
# stretching arm      : 0.998
# massaging neck      : 0.001
# playing harp        : 0.000
# tai chi             : 0.000
# contact juggling    : 0.000

# %% [markdown]
# Convert the sequence of probabilities into a video:

# %%
# Generate a plot and output to a video tensor
plot_video = plot_streaming_top_preds(probs, video, video_fps=8.)
# Out:
#   0%|          | 0/307 [00:00<?, ?it/s]<ipython-input-27-d3b894631895>:112: MatplotlibDeprecationWarning: The tostring_rgb function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use buffer_rgba instead.
#   data = np.frombuffer(fig.canvas.tostring_rgb(), dtype=np.uint8)
# 100%|██████████| 307/307 [03:05<00:00,  1.66it/s]

# %%
# For gif format, set codec='gif'
media.show_video(plot_video, fps=3)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="464" height="500" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# ## Resources
#
# The pretrained models are available from [TF Hub](https://tfhub.dev/google/collections/movinet/1). The TF Hub collection also includes quantized models optimized for [TFLite](https://tensorflow.org/lite).
#
# The source for these models is available in the [TensorFlow Model Garden](https://github.com/tensorflow/models/tree/master/official/projects/movinet). This includes a [longer version of this tutorial](https://colab.sandbox.google.com/github/tensorflow/models/blob/master/official/projects/movinet/movinet_tutorial.ipynb) that also covers building and fine-tuning a MoViNet model.

# %% [markdown]
# ## Next Steps
#
# To learn more about working with video data in TensorFlow, check out the following tutorials:
#
# * [Load video data](https://www.tensorflow.org/tutorials/load_data/video)
# * [Build a 3D CNN model for video classification](https://www.tensorflow.org/tutorials/video/video_classification)
# * [Transfer learning for video classification with MoViNet](https://www.tensorflow.org/tutorials/video/transfer_learning_with_movinet)
